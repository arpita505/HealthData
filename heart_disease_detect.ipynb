# %% [markdown]
# # Heart Disease Prediction using Neural Networks

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import keras

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
# the names will be the names of each column in our pandas DataFrame
names = ['age',
        'sex',
        'cp',
        'trestbps',
        'chol',
        'fbs',
        'restecg',
        'thalach',
        'exang',
        'oldpeak',
        'slope',
        'ca',
        'thal',
        'class']
# import the heart disease dataset
clev = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data",names = names)

# %%
print(clev.shape)
print(clev.loc[1])
# Out:
# (303, 14)
# age          67
# sex           1
# cp            4
# trestbps    160
# chol        286
# fbs           0
# restecg       2
# thalach     108
# exang         1
# oldpeak     1.5
# slope         2
# ca          3.0
# thal        3.0
# class         2
# Name: 1, dtype: object

# %%
data = clev[~clev.isin(['?'])]
data = data.dropna(axis=0)
print (data.shape)
print (data.dtypes)
# Out:
# (297, 14)
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
data.hist(figsize = (12, 12))
plt.show()
